# %% [markdown]
# # Files holen und laden

# %%
import time
import csv
import pandas as pd
import re
import os
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np


# Files holen
file_path_A = os.path.join(os.getcwd(), '..','..', 'data/MM_stage3.csv')
file_path_B = os.path.join(os.getcwd(), '..', 'data/stage3.csv')
# Files lesen/laden
df_Mediamarkt = pd.read_csv(file_path_A,
                            encoding='UTF-8')
df_Galaxus = pd.read_csv(file_path_B,
                            encoding='UTF-8')

# %%
df_Galaxus.head()
# Out:
#    Preis    Marke         Modell  Speicher              Farbe  Display
# 0  499.0  Samsung  Galaxy A54 5G     256.0   Awesome Graphite      6.4  \
# 1  399.0  Samsung  Galaxy A53 5G     128.0       Awesome Blue      6.5
# 2  333.0   Google       Pixel 6a     128.0           Charcoal      6.1
# 3  949.0  Samsung     Galaxy S23     256.0              Green      6.1
# 4  769.0    Apple      iPhone 14     128.0           Midnight      6.1
#
#     Kamera Mobilfunk                Produkt  Marke_Prozent  Funk_Prozent
# 0      50         5G  Samsung Galaxy A54 5G          17.74         59.04
# 1      64         5G  Samsung Galaxy A53 5G          17.74         59.04
# 2   12.20         5G        Google Pixel 6a           2.15         59.04
# 3      50         5G     Samsung Galaxy S23          17.74         59.04
# 4      12         5G        Apple iPhone 14          16.29         59.04

# %%
df_Mediamarkt.head()
# Out:
#                                                  Url  Med_Preis
# 0  https://www.mediamarkt.ch/de/product/_apple-ip...     1100.0  \
# 1  https://www.mediamarkt.ch/de/product/_apple-ip...      719.0
# 2  https://www.mediamarkt.ch/de/product/_apple-ip...     1125.0
# 3  https://www.mediamarkt.ch/de/product/_apple-ip...      429.0
# 4  https://www.mediamarkt.ch/de/product/_apple-ip...      768.0
#
#            Modelname       GTIN        Farbe  Rückkamera_MP  Front_Kamera_MP
# 0      iPhone 14 Pro  MQ0T3ZD/A  Space Black           48.0             12.0  \
# 1          iPhone 13  MLPF3ZD/A     Midnight           12.0             12.0
# 2  iPhone 14 Pro Max  MQ9P3ZD/A  Space Black           48.0             12.0
# 3   iPhone 11 (2020)  MHDA3ZD/A        Black           12.0             12.0
# 4          iPhone 14  MPUF3ZD/A     Midnight           12.0             12.0
#
#    Displaygrösse_Inches  Speicherkapazität_GB  Gesichtserkennung  Modelljahr
# 0                   6.1                 256.0                1.0      2022.0  \
# 1                   6.1                 128.0                1.0      2021.0
# 2                   6.7                 128.0                1.0      2022.0
# 3                   6.1                  64.0                1.0      2020.0
# 4                   6.1                 128.0                1.0      2022.0
#
#    Marke  Gesamtkundenbewertung  Anzahl_Kundenbewertung  Displaygrösse_CM
# 0  apple                    4.0                    16.0              15.5  \
# 1  apple                    4.0                    56.0              15.5
# 2  apple                    4.0                     8.0              17.0
# 3  apple                    4.0                    62.0              15.5
# 4  apple                    4.0                     9.0              15.5
#
#    Med_Preis_Exkl_Mwst Kategorie_Farbe
# 0               1015.0         schwarz
# 1                664.0            rest
# 2               1038.0         schwarz
# 3                396.0         schwarz
# 4                709.0            rest

# %% [markdown]
# # DataFrames optimieren

# %% [markdown]
# ## Media Markt

# %%
# Bevor wir den Merge machen können, müssen ein Optimierungen auf beiden Datensätzen gemacht werden

# %%
# Spaltennamen von den Spalten, die für den Merge relevant sind ändern, so dass sie gleich sind wie die Namen vom Galaxus Datensatz
# Spaltennamen mit Umlaute umbenennen
# Spaltennamen der Spalten, die eindeutig der Webseite zugeteilt werden könenn mit 'Med_' ergänzen (z.B. Gesichterkennung hat auf beiden Seiten für ein Produkt denselben Wert. Preis wiederum wird der Webseite zugetilt und unterscheidet sich vom Preis von Galaxus. Diese müssen nach dem Merge klar erkennbar sein, als Preis von Media Markt)
df_Mediamarkt = df_Mediamarkt.rename(columns={'Url':'Med_Url', 'Displaygrösse_Inches': 'Display', 'Modelname':'Modell', 'Rückkamera_MP': 'Rueckkamera_MP','Speicherkapazität_GB':'Speicher','Displaygrösse_CM':'Display_CM', 'Gesamtkundenbewertung':'Med_Gesamtkundenbewertung', 'Anzahl_Kundenbewertung':'Med_Anzahl_Kundenbewertung', 'Front_Kamera_MP':'Frontkamera'})

# %%
#Spalte Marke ist alles klein geschrieben. Im anderen Datensatz ist der erste Buchstaben gross. Das ist ein Problem dann beim merge, da merge case sensitive ist.
#Es ist noch nicht klar, ob wir diese Spalte für den Merge benötigen. hier wird die Spalte angepasst so dass der erste Buchstaben gross geschrieben wird.
df_Mediamarkt['Marke'] = df_Mediamarkt['Marke'].str.title()

# %%
df_Mediamarkt.sample(3)
# Out:
#                                                Med_Url  Med_Preis
# 360  https://www.mediamarkt.ch/de/product/_oppo-fin...     359.00  \
# 284  https://www.mediamarkt.ch/de/product/_samsung-...     459.95
# 100  https://www.mediamarkt.ch/de/product/_apple-ip...     469.95
#
#                Modell            GTIN            Farbe  Rueckkamera_MP
# 360       Find X3 Neo         5988253  Galactic Silver            50.0  \
# 284     Galaxy A54 5G  SM-A546BZWCEUE    Awesome White            50.0
# 100  iPhone SE (2022)       MMXH3ZD/A     (PRODUCT)RED            12.0
#
#      Frontkamera  Display  Speicher  Gesichtserkennung  Modelljahr    Marke
# 360         32.0      6.5     256.0                1.0      2021.0     Oppo  \
# 284         32.0      6.4     128.0                0.0         0.0  Samsung
# 100          7.0      4.7      64.0                0.0         0.0    Apple
#
#      Med_Gesamtkundenbewertung  Med_Anzahl_Kundenbewertung  Display_CM
# 360                        0.0                         0.0        16.5  \
# 284                        0.0                         0.0        16.3
# 100                        0.0                         0.0        11.9
#
#      Med_Preis_Exkl_Mwst Kategorie_Farbe
# 360                331.0            rest
# 284                425.0            rest
# 100                434.0            rest

# %%
# Datentyp vom Modelljahr anpassen zu INT. Jahr kann nicht FLOAT sein
df_Mediamarkt['Modelljahr'] = df_Mediamarkt['Modelljahr'].astype(int)

# %%
df_Mediamarkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Med_Url                     374 non-null    object
#  1   Med_Preis                   374 non-null    float64
#  2   Modell                      374 non-null    object
#  3   GTIN                        374 non-null    object
#  4   Farbe                       374 non-null    object
#  5   Rueckkamera_MP              374 non-null    float64
#  6   Frontkamera                 374 non-null    float64
#  7   Display                     374 non-null    float64
#  8   Speicher                    374 non-null    float64
#  9   Gesichtserkennung           374 non-null    float64
#  10  Modelljahr                  374 non-null    int64
#  11  Marke                       374 non-null    object
#  12  Med_Gesamtkundenbewertung   374 non-null    float64
#  13  Med_Anzahl_Kundenbewertung  374 non-null    float64
#  14  Display_CM                  374 non-null    float64
#  15  Med_Preis_Exkl_Mwst         374 non-null    float64
#  16  Kategorie_Farbe             374 non-null    object
# dtypes: float64(10), int64(1), object(6)
# memory usage: 49.8+ KB

# %% [markdown]
# #### Spalten löschen

# %%
# Die Produkte können anhand der Spalten Modell, Farbe und Speicher eindeutig identifiziert werden. Diese drei Spalten sind relevant für den Merge.
# Neben diesen Spalten gibt es jedoch noch weitere Spalten, die doppelt vorhanden sind. Diese werden nun hier entfernt

# %%
df_Mediamarkt.drop(columns=['Med_Url','Rueckkamera_MP', 'Display', 'Marke','Med_Preis_Exkl_Mwst'], inplace=True, axis=1)

# %% [markdown]
# ## Galaxus

# %%
# nun dasselbe mit Galaxus

# %%
#Spalten umbenennen
df_Galaxus = df_Galaxus.rename(columns={'Preis':'Gal_Preis','Kamera':'Rueckkamera', 'Marke_Prozent': 'Gal_Markenanteil', 'Funk_Prozent':'Gal_Mobilfunkanteil', 'Display':'Display_Inches'})

# %%
df_Galaxus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1443 entries, 0 to 1442
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gal_Preis            1443 non-null   float64
#  1   Marke                1443 non-null   object
#  2   Modell               1443 non-null   object
#  3   Speicher             1443 non-null   float64
#  4   Farbe                1443 non-null   object
#  5   Display_Inches       1443 non-null   float64
#  6   Rueckkamera          1443 non-null   object
#  7   Mobilfunk            1443 non-null   object
#  8   Produkt              1443 non-null   object
#  9   Gal_Markenanteil     1443 non-null   float64
#  10  Gal_Mobilfunkanteil  1443 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 124.1+ KB

# %% [markdown]
# # Merge

# %% [markdown]
# ## Versuch 1

# %%
# Versuch Nummer 1 von einem Merge anhand von drei Spalten - Modell, Speicher und Farbe.
df_Merged = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Modell','Speicher','Farbe'], right_on=['Modell','Speicher','Farbe'])

# %%
# Leider kein Erfolg
df_Merged.head()
# Out:
# Empty DataFrame
# Columns: [Med_Preis, Modell, GTIN, Farbe, Frontkamera, Speicher, Gesichtserkennung, Modelljahr, Med_Gesamtkundenbewertung, Med_Anzahl_Kundenbewertung, Display_CM, Kategorie_Farbe, Gal_Preis, Marke, Display_Inches, Rueckkamera, Mobilfunk, Produkt, Gal_Markenanteil, Gal_Mobilfunkanteil]
# Index: []

# %% [markdown]
# ## Versuch 2

# %%
# Nun müssen wir herausfinden an welcher Spalte der Merge scheitert. Daher testen wir nun Merge anhand jeder Spalte einzeln durch - Ausschlussprinzip.

# %% [markdown]
# #### Merge 'Modell'

# %%
df_MergedModell = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Modell'], right_on=['Modell'])

# %%
# Merge anhand der Spalte Modell funktioniert
df_MergedModell.head()
# Out:
#    Med_Preis         Modell       GTIN      Farbe_x  Frontkamera  Speicher_x
# 0     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0       256.0  \
# 1     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0       256.0
# 2     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0       256.0
# 3     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0       256.0
# 4     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0       256.0
#
#    Gesichtserkennung  Modelljahr  Med_Gesamtkundenbewertung
# 0                1.0        2022                        4.0  \
# 1                1.0        2022                        4.0
# 2                1.0        2022                        4.0
# 3                1.0        2022                        4.0
# 4                1.0        2022                        4.0
#
#    Med_Anzahl_Kundenbewertung  ...  Gal_Preis  Marke  Speicher_y
# 0                        16.0  ...     1129.0  Apple       256.0  \
# 1                        16.0  ...     1125.0  Apple       256.0
# 2                        16.0  ...     1029.0  Apple       128.0
# 3                        16.0  ...     1125.0  Apple       256.0
# 4                        16.0  ...     1029.0  Apple       128.0
#
#         Farbe_y  Display_Inches Rueckkamera  Mobilfunk              Produkt
# 0   Space Black             6.1         48          5G  Apple iPhone 14 Pro  \
# 1   Deep Purple             6.1         48          5G  Apple iPhone 14 Pro
# 2   Deep Purple             6.1         48          5G  Apple iPhone 14 Pro
# 3        Silver             6.1         48          5G  Apple iPhone 14 Pro
# 4        Silver             6.1         48          5G  Apple iPhone 14 Pro
#
#   Gal_Markenanteil Gal_Mobilfunkanteil
# 0            16.29               59.04
# 1            16.29               59.04
# 2            16.29               59.04
# 3            16.29               59.04
# 4            16.29               59.04
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Merge 'Speicher'

# %%
df_MergedSpeicher = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Speicher'], right_on=['Speicher'])

# %%
# Merge anhand der Spalte Speicher funktioniert. Somit könnte es nur noch die Spalte Farbe sein. Testen wir dies mal.
df_MergedSpeicher.head()
# Out:
#    Med_Preis       Modell_x       GTIN      Farbe_x  Frontkamera  Speicher
# 0     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0     256.0  \
# 1     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0     256.0
# 2     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0     256.0
# 3     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0     256.0
# 4     1100.0  iPhone 14 Pro  MQ0T3ZD/A  Space Black         12.0     256.0
#
#    Gesichtserkennung  Modelljahr  Med_Gesamtkundenbewertung
# 0                1.0        2022                        4.0  \
# 1                1.0        2022                        4.0
# 2                1.0        2022                        4.0
# 3                1.0        2022                        4.0
# 4                1.0        2022                        4.0
#
#    Med_Anzahl_Kundenbewertung  ...  Gal_Preis    Marke       Modell_y
# 0                        16.0  ...      499.0  Samsung  Galaxy A54 5G  \
# 1                        16.0  ...      949.0  Samsung     Galaxy S23
# 2                        16.0  ...     1129.0    Apple  iPhone 14 Pro
# 3                        16.0  ...      949.0  Samsung     Galaxy S23
# 4                        16.0  ...      949.0  Samsung     Galaxy S23
#
#              Farbe_y Display_Inches Rueckkamera  Mobilfunk
# 0   Awesome Graphite            6.4         50          5G  \
# 1              Green            6.1         50          5G
# 2        Space Black            6.1         48          5G
# 3      Phantom Black            6.1         50          5G
# 4           Lavender            6.1         50          5G
#
#                  Produkt Gal_Markenanteil Gal_Mobilfunkanteil
# 0  Samsung Galaxy A54 5G            17.74               59.04
# 1     Samsung Galaxy S23            17.74               59.04
# 2    Apple iPhone 14 Pro            16.29               59.04
# 3     Samsung Galaxy S23            17.74               59.04
# 4     Samsung Galaxy S23            17.74               59.04
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Merge 'Farbe'

# %%
df_MergedFarbe = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Farbe'], right_on=['Farbe'])

# %%
# Nicht erfolgreich. Somit haben wir ein Problem mit der Spalte Farbe.
df_MergedFarbe.head()
# Out:
# Empty DataFrame
# Columns: [Med_Preis, Modell_x, GTIN, Farbe, Frontkamera, Speicher_x, Gesichtserkennung, Modelljahr, Med_Gesamtkundenbewertung, Med_Anzahl_Kundenbewertung, Display_CM, Kategorie_Farbe, Gal_Preis, Marke, Modell_y, Speicher_y, Display_Inches, Rueckkamera, Mobilfunk, Produkt, Gal_Markenanteil, Gal_Mobilfunkanteil]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Evtl. haben wir ein Problem mit dem Datentyp. Ändern wir mal den Datentyp zu String (wenn nicht schon der Fall).

# %%
print(df_Mediamarkt['Farbe'].dtype)
# Out:
# object

# %%
print(df_Galaxus['Farbe'].dtype)
# Out:
# object

# %%
df_Galaxus['Farbe'] = df_Galaxus['Farbe'].astype(str)

# %%
df_Mediamarkt['Farbe'] = df_Mediamarkt['Farbe'].astype(str)

# %%
df_Merged2 = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Modell','Speicher','Farbe'], right_on=['Modell','Speicher','Farbe'])

# %%
# auch kein Erfolg
df_Merged2.head()
# Out:
# Empty DataFrame
# Columns: [Med_Preis, Modell, GTIN, Farbe, Frontkamera, Speicher, Gesichtserkennung, Modelljahr, Med_Gesamtkundenbewertung, Med_Anzahl_Kundenbewertung, Display_CM, Kategorie_Farbe, Gal_Preis, Marke, Display_Inches, Rueckkamera, Mobilfunk, Produkt, Gal_Markenanteil, Gal_Mobilfunkanteil]
# Index: []

# %% [markdown]
# ## Versuch 3

# %%
# Was wenn Leerschläge bestehen, die den Match zwischen beiden Spalten verunmöglichen. Ersetzen wir mal alle Leerschläge.

# %%
df_Galaxus['Farbe'] = df_Galaxus['Farbe'].str.replace(' ', '')
df_Mediamarkt['Farbe'] = df_Mediamarkt['Farbe'].str.replace(' ', '')

# %%
df_Merged3 = pd.merge(df_Mediamarkt, df_Galaxus, left_on=['Modell','Speicher','Farbe'], right_on=['Modell','Speicher','Farbe'])

# %%
# Merge ist erfolgreich!!!
df_Merged3.head()
df_Merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Med_Preis                   208 non-null    float64
#  1   Modell                      208 non-null    object
#  2   GTIN                        208 non-null    object
#  3   Farbe                       208 non-null    object
#  4   Frontkamera                 208 non-null    float64
#  5   Speicher                    208 non-null    float64
#  6   Gesichtserkennung           208 non-null    float64
#  7   Modelljahr                  208 non-null    int64
#  8   Med_Gesamtkundenbewertung   208 non-null    float64
#  9   Med_Anzahl_Kundenbewertung  208 non-null    float64
#  10  Display_CM                  208 non-null    float64
#  11  Kategorie_Farbe             208 non-null    object
#  12  Gal_Preis                   208 non-null    float64
#  13  Marke                       208 non-null    object
#  14  Display_Inches              208 non-null    float64
#  15  Rueckkamera                 208 non-null    object
#  16  Mobilfunk                   208 non-null    object
#  17  Produkt                     208 non-null    object
#  18  Gal_Markenanteil            208 non-null    float64
#  19  Gal_Mobilfunkanteil         208 non-null    float64
# dtypes: float64(11), int64(1), object(8)
# memory usage: 32.6+ KB

# %% [markdown]
# # Tabelle modifizieren

# %%
# Reihenfolge der Spalten anpassen, so dass die Informationen nach Wichtigkeit geordnet sind und Daten wie Preise nebeneinander aufgelistet werden
df_Merged3 = df_Merged3[['GTIN',
                         'Marke',
                         'Modell',
                         'Farbe',
                         'Speicher',
                         'Display_Inches',
                         'Display_CM',
                         'Mobilfunk',
                         'Rueckkamera',
                         'Frontkamera',
                         'Modelljahr',
                         'Gesichtserkennung',
                         'Produkt',
                         'Kategorie_Farbe',
                         'Med_Preis',
                         'Gal_Preis',
                         'Med_Gesamtkundenbewertung',
                         'Med_Anzahl_Kundenbewertung',
                         'Gal_Markenanteil',
                         'Gal_Mobilfunkanteil'
                        ]]

# %%
df_Merged3.head()
# Out:
#         GTIN  Marke             Modell       Farbe  Speicher  Display_Inches
# 0  MQ0T3ZD/A  Apple      iPhone 14 Pro  SpaceBlack     256.0             6.1  \
# 1  MLPF3ZD/A  Apple          iPhone 13    Midnight     128.0             6.1
# 2  MQ9P3ZD/A  Apple  iPhone 14 Pro Max  SpaceBlack     128.0             6.7
# 3  MPUF3ZD/A  Apple          iPhone 14    Midnight     128.0             6.1
# 4  MQ1F3ZD/A  Apple      iPhone 14 Pro  DeepPurple     256.0             6.1
#
#    Display_CM Mobilfunk Rueckkamera  Frontkamera  Modelljahr
# 0        15.5        5G         48          12.0        2022  \
# 1        15.5        5G         12          12.0        2021
# 2        17.0        5G         48          12.0        2022
# 3        15.5        5G         12          12.0        2022
# 4        15.5        5G         48          12.0        2022
#
#    Gesichtserkennung                  Produkt Kategorie_Farbe  Med_Preis
# 0                1.0      Apple iPhone 14 Pro         schwarz     1100.0  \
# 1                1.0          Apple iPhone 13            rest      719.0
# 2                1.0  Apple iPhone 14 Pro Max         schwarz     1125.0
# 3                1.0          Apple iPhone 14            rest      768.0
# 4                1.0      Apple iPhone 14 Pro            rest     1132.0
#
#    Gal_Preis  Med_Gesamtkundenbewertung  Med_Anzahl_Kundenbewertung
# 0     1129.0                        4.0                        16.0  \
# 1      726.0                        4.0                        56.0
# 2     1100.0                        4.0                         8.0
# 3      769.0                        4.0                         9.0
# 4     1125.0                        4.0                        16.0
#
#    Gal_Markenanteil  Gal_Mobilfunkanteil
# 0             16.29                59.04
# 1             16.29                59.04
# 2             16.29                59.04
# 3             16.29                59.04
# 4             16.29                59.04

# %%
# GTIN ist eindeutig - somit geeignet als Primary Key. GTIN zu Primary Key/Index ändern
df_Merged3.set_index('GTIN', inplace = True)

# %%
# Nun ergänzen wir die Tabelle mit der Spalte 'Preisdifferenz'. Diesen Wert werden wir für die Beantwortung der Fragen benötigen.
df_Merged3['Preisdifferenz'] = df_Merged3['Gal_Preis'] - df_Merged3['Med_Preis']

# %% [markdown]
# ### Export

# %%
# exportieren in ein CSV
file_path = os.path.join(os.getcwd(), '..', 'data/merged.csv')
df_Merged3.to_csv(file_path, index=False)

# %%
df_Merged3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, MQ0T3ZD/A to GA03923-GB
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Marke                       208 non-null    object
#  1   Modell                      208 non-null    object
#  2   Farbe                       208 non-null    object
#  3   Speicher                    208 non-null    float64
#  4   Display_Inches              208 non-null    float64
#  5   Display_CM                  208 non-null    float64
#  6   Mobilfunk                   208 non-null    object
#  7   Rueckkamera                 208 non-null    object
#  8   Frontkamera                 208 non-null    float64
#  9   Modelljahr                  208 non-null    int64
#  10  Gesichtserkennung           208 non-null    float64
#  11  Produkt                     208 non-null    object
#  12  Kategorie_Farbe             208 non-null    object
#  13  Med_Preis                   208 non-null    float64
#  14  Gal_Preis                   208 non-null    float64
#  15  Med_Gesamtkundenbewertung   208 non-null    float64
#  16  Med_Anzahl_Kundenbewertung  208 non-null    float64
#  17  Gal_Markenanteil            208 non-null    float64
#  18  Gal_Mobilfunkanteil         208 non-null    float64
#  19  Preisdifferenz              208 non-null    float64
# dtypes: float64(12), int64(1), object(7)
# memory usage: 34.1+ KB

# %% [markdown]
# # Visualisierung

# %%
# Fragen 2 & 3 beantworten

# %% [markdown]
# #### Wie hoch ist die Wahrscheintlichkeit, dass ein Produkt bei Galaxus im Vergleich zu Media Markt günstiger ist?

# %%
# hier werden der Durchschnittspreis pro Marke von beiden Seiten einander gegenübergestellt.
# Wir können hier rauslesen, dass generell Media Markt höhere Preise hat als Galaxus.
mean_prices = df_Merged3.groupby('Marke')[['Gal_Preis','Med_Preis']].mean()
fig, ax = plt.subplots()
mean_prices.plot(kind='bar', ax=ax)
ax.set_xlabel('Marke')
ax.set_ylabel('Durchschnittspreis')
ax.set_title('Preis im Durchschnitt pro Marke')
plt.show()

# %%
# Wir haben vorhin die Preisdifferenz pro Zeile berechnet. Hier werden wir die Preisdifferenz visualisieren.

# %%
df_Merged3['Preisdifferenz'].plot.box()
plt.title('Preisdifferenz zwischen Galaxus und Media Markt')
plt.show()

# Jetzt berechnen wir die Werte noch zusätzlich
median = np.median(df_Merged3['Preisdifferenz'])
q1 = np.percentile(df_Merged3['Preisdifferenz'], 25)
q3 = np.percentile(df_Merged3['Preisdifferenz'], 75)
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
print('Median:', median)
print('1. Quartil:',q1)
print('3. Quartil:',q3)
print('Interquartilsabstand:', iqr)
print('Untere Grenze:', lower_fence)
print('Obere Grenze:', upper_fence)
# Out:
# Median: -13.379999999999988
# 1. Quartil: -50.0
# 3. Quartil: 0.0
# Interquartilsabstand: 50.0
# Untere Grenze: -125.0
# Obere Grenze: 75.0

# %%
# Interpretation Preisdifferenz:
# Der Median-Wert beträgt -13.38. Das heisst Hälfte der Preisdifferenz liegt unter -13.3. Die ander Hälfte ist grösser. Somit sind 50% der Preise mehr als 13.30 Franken günstiger sind bei Galaxus. 
# 25% der Preisunterschiede liegt unter -50. 75% ist grösser. 25% der Produkte sind bei Galaxus um 50.- günstiger als bei Media Markt.
# 75% der Preisunterschiede liegen unter 0. Somit sind 75% der Produkte bei Galaxus günstiger als bei Media Markt.
# Dabei dürfen wir die Ausreisser nicht vergessen. Die untere Aussreissergrenze liegt bei -125. Alles darunter sind potenzielle Ausreisser.
# Nach oben liegt die Grenze bei 75.-

# %%
# Schauen wir mal die Ausreisser an

df_Merged3[df_Merged3["Preisdifferenz"] < -125]
# Out:
#                    Marke             Modell          Farbe  Speicher
# GTIN
# MPX33ZD/A          Apple          iPhone 14      Starlight     512.0  \
# MPWW3ZD/A          Apple          iPhone 14       Midnight     512.0
# SM-F721BLVGEUE   Samsung     Galaxy Z Flip4     BoraPurple     128.0
# SM-F721BZAGEUE   Samsung     Galaxy Z Flip4       Graphite     128.0
# MPXN3ZD/A          Apple          iPhone 14           Blue     512.0
# MZB0DBIEU         Xiaomi             13 Pro   CeramicBlack     256.0
# PAU70018IT      Motorola           Moto G52   CharcoalGrey     128.0
# MLKD3ZD/A          Apple     iPhone 13 mini           Pink     512.0
# MLQC3ZD/A          Apple          iPhone 13       Midnight     512.0
# MQ593ZD/A          Apple     iPhone 14 Plus       Midnight     512.0
# SM-F721BZAPEUE   Samsung     Galaxy Z Flip4       Graphite     512.0
# SM-F926BZKDEUC   Samsung  Galaxy Z Fold3 5G   PhantomBlack     256.0
# SM-F926BZSGEUC   Samsung  Galaxy Z Fold3 5G  PhantomSilver     512.0
# SM-F926BZKGEUC   Samsung  Galaxy Z Fold3 5G   PhantomBlack     512.0
# 5991409             OPPO        Find X3 Pro     GlossBlack     256.0
#
#                 Display_Inches  Display_CM Mobilfunk Rueckkamera  Frontkamera
# GTIN
# MPX33ZD/A                 6.10        15.5        5G         12          12.0  \
# MPWW3ZD/A                 6.10        15.5        5G         12          12.0
# SM-F721BLVGEUE            6.70        17.0        5G         12          10.0
# SM-F721BZAGEUE            6.70        17.0        5G         12          10.0
# MPXN3ZD/A                 6.10        15.5        5G         12          12.0
# MZB0DBIEU                 6.73        17.1        5G         50          32.0
# PAU70018IT                6.60        16.8        4G         50          16.0
# MLKD3ZD/A                 5.40        13.7        5G         12          12.0
# MLQC3ZD/A                 6.10        15.5        5G         12          12.0
# MQ593ZD/A                 6.70        17.0        5G         12          12.0
# SM-F721BZAPEUE            6.70        17.0        5G         12          10.0
# SM-F926BZKDEUC            7.60        19.3        5G         12          10.0
# SM-F926BZSGEUC            7.60        19.3        5G         12          10.0
# SM-F926BZKGEUC            7.60        19.3        5G         12          10.0
# 5991409                   6.70        17.0        5G         50          32.0
#
#                 Modelljahr  Gesichtserkennung                    Produkt
# GTIN
# MPX33ZD/A             2022                1.0            Apple iPhone 14  \
# MPWW3ZD/A             2022                1.0            Apple iPhone 14
# SM-F721BLVGEUE        2022                1.0     Samsung Galaxy Z Flip4
# SM-F721BZAGEUE        2022                1.0     Samsung Galaxy Z Flip4
# MPXN3ZD/A             2022                1.0            Apple iPhone 14
# MZB0DBIEU             2023                1.0              Xiaomi 13 Pro
# PAU70018IT            2022                1.0          Motorola Moto G52
# MLKD3ZD/A             2021                1.0       Apple iPhone 13 mini
# MLQC3ZD/A             2021                1.0            Apple iPhone 13
# MQ593ZD/A             2022                1.0       Apple iPhone 14 Plus
# SM-F721BZAPEUE        2022                1.0     Samsung Galaxy Z Flip4
# SM-F926BZKDEUC        2021                1.0  Samsung Galaxy Z Fold3 5G
# SM-F926BZSGEUC        2021                1.0  Samsung Galaxy Z Fold3 5G
# SM-F926BZKGEUC        2021                1.0  Samsung Galaxy Z Fold3 5G
# 5991409               2021                1.0           OPPO Find X3 Pro
#
#                Kategorie_Farbe  Med_Preis  Gal_Preis
# GTIN
# MPX33ZD/A                 rest    1269.00    1135.00  \
# MPWW3ZD/A                 rest    1269.00    1134.00
# SM-F721BLVGEUE            rest     999.00     862.17
# SM-F721BZAGEUE            rest     999.00     699.75
# MPXN3ZD/A                 rest    1269.00    1138.00
# MZB0DBIEU                weiss    1399.00    1126.00
# PAU70018IT                rest     329.95     181.41
# MLKD3ZD/A                 rest     999.00     867.00
# MLQC3ZD/A                 rest    1139.00     905.00
# MQ593ZD/A                 rest    1379.00    1192.00
# SM-F721BZAPEUE           weiss    1149.00     900.30
# SM-F926BZKDEUC            rest    1437.00     970.20
# SM-F926BZSGEUC            rest    1649.00     973.50
# SM-F926BZKGEUC            rest    1519.00    1147.00
# 5991409                   rest     899.00     499.00
#
#                 Med_Gesamtkundenbewertung  Med_Anzahl_Kundenbewertung
# GTIN
# MPX33ZD/A                             0.0                         0.0  \
# MPWW3ZD/A                             0.0                         0.0
# SM-F721BLVGEUE                        4.0                        16.0
# SM-F721BZAGEUE                        4.0                        15.0
# MPXN3ZD/A                             0.0                         0.0
# MZB0DBIEU                             5.0                         2.0
# PAU70018IT                            0.0                         0.0
# MLKD3ZD/A                             5.0                         2.0
# MLQC3ZD/A                             5.0                         1.0
# MQ593ZD/A                             5.0                         1.0
# SM-F721BZAPEUE                        3.0                        16.0
# SM-F926BZKDEUC                        4.0                         1.0
# SM-F926BZSGEUC                        0.0                         0.0
# SM-F926BZKGEUC                        4.0                         2.0
# 5991409                               0.0                         0.0
#
#                 Gal_Markenanteil  Gal_Mobilfunkanteil  Preisdifferenz
# GTIN
# MPX33ZD/A                  16.29                59.04         -134.00
# MPWW3ZD/A                  16.29                59.04         -135.00
# SM-F721BLVGEUE             17.74                59.04         -136.83
# SM-F721BZAGEUE             17.74                59.04         -299.25
# MPXN3ZD/A                  16.29                59.04         -131.00
# MZB0DBIEU                  22.18                59.04         -273.00
# PAU70018IT                  8.94                39.02         -148.54
# MLKD3ZD/A                  16.29                59.04         -132.00
# MLQC3ZD/A                  16.29                59.04         -234.00
# MQ593ZD/A                  16.29                59.04         -187.00
# SM-F721BZAPEUE             17.74                59.04         -248.70
# SM-F926BZKDEUC             17.74                59.04         -466.80
# SM-F926BZSGEUC             17.74                59.04         -675.50
# SM-F926BZKGEUC             17.74                59.04         -372.00
# 5991409                     6.31                59.04         -400.00

# %%
# bei Verifizierung mit der Webseite, scheint es bei Galaxus teilweise Rabatte zu geben auf gewisse Modelle, daher gibt es einen so grossen Preisunterschied.

# %%
# Schauen wir mal die Ausreisser nach oben an an

df_Merged3[df_Merged3["Preisdifferenz"] > 75]
# Out:
#                Marke             Modell             Farbe  Speicher
# GTIN
# MQ293ZD/A      Apple      iPhone 14 Pro        DeepPurple     512.0  \
# PALM0002FR  Motorola          Moto G 5G     FrostedSilver      64.0
# MQAJ3ZD/A      Apple  iPhone 14 Pro Max              Gold     512.0
# MQ2G3ZD/A      Apple      iPhone 14 Pro        SpaceBlack    1000.0
# MQ233ZD/A      Apple      iPhone 14 Pro              Gold     512.0
# PALM0016IS  Motorola          Moto G 5G      VolcanicGrey      64.0
# PANY0039SE  Motorola        Edge 20 Pro  BlueVeganLeather     256.0
# 5988253         OPPO        Find X3 Neo    GalacticSilver     256.0
#
#             Display_Inches  Display_CM Mobilfunk Rueckkamera  Frontkamera
# GTIN
# MQ293ZD/A              6.1        15.5        5G         48          12.0  \
# PALM0002FR             6.7        17.0        5G         48          16.0
# MQAJ3ZD/A              6.7        17.0        5G         48          12.0
# MQ2G3ZD/A              6.1        15.5        5G         48          12.0
# MQ233ZD/A              6.1        15.5        5G         48          12.0
# PALM0016IS             6.7        17.0        5G         48          16.0
# PANY0039SE             6.7        17.0        5G        108          32.0
# 5988253                6.5        16.5        5G         50          32.0
#
#             Modelljahr  Gesichtserkennung                  Produkt
# GTIN
# MQ293ZD/A         2022                1.0      Apple iPhone 14 Pro  \
# PALM0002FR        2020                1.0       Motorola Moto G 5G
# MQAJ3ZD/A         2022                1.0  Apple iPhone 14 Pro Max
# MQ2G3ZD/A         2022                1.0      Apple iPhone 14 Pro
# MQ233ZD/A         2022                1.0      Apple iPhone 14 Pro
# PALM0016IS        2020                1.0       Motorola Moto G 5G
# PANY0039SE        2021                1.0     Motorola Edge 20 Pro
# 5988253           2021                1.0         OPPO Find X3 Neo
#
#            Kategorie_Farbe  Med_Preis  Gal_Preis  Med_Gesamtkundenbewertung
# GTIN
# MQ293ZD/A             rest     1439.0    1587.35                        5.0  \
# PALM0002FR            rest      239.0     368.00                        0.0
# MQAJ3ZD/A          schwarz     1559.0    1707.45                        5.0
# MQ2G3ZD/A             rest     1679.0    1840.55                        5.0
# MQ233ZD/A             rest     1406.0    1574.81                        0.0
# PALM0016IS            rest      239.0     448.00                        0.0
# PANY0039SE            rest      529.0     656.00                        0.0
# 5988253               rest      359.0     684.00                        0.0
#
#             Med_Anzahl_Kundenbewertung  Gal_Markenanteil  Gal_Mobilfunkanteil
# GTIN
# MQ293ZD/A                          1.0             16.29                59.04  \
# PALM0002FR                         0.0              8.94                59.04
# MQAJ3ZD/A                          1.0             16.29                59.04
# MQ2G3ZD/A                          2.0             16.29                59.04
# MQ233ZD/A                          0.0             16.29                59.04
# PALM0016IS                         0.0              8.94                59.04
# PANY0039SE                         0.0              8.94                59.04
# 5988253                            0.0              6.31                59.04
#
#             Preisdifferenz
# GTIN
# MQ293ZD/A           148.35
# PALM0002FR          129.00
# MQAJ3ZD/A           148.45
# MQ2G3ZD/A           161.55
# MQ233ZD/A           168.81
# PALM0016IS          209.00
# PANY0039SE          127.00
# 5988253             325.00

# %%
# rückwirkend können wir nicht sagen, was sich hier an den Preisen geändert hat. Diese Preise sind nicht die aktuellen Preise.

# %% [markdown]
# ##### Wahrscheinlichkeit

# %%
# Hier berechnen wir nun die Wahrscheinlichkeit, dass der Wert in der Spalte Gal_Preis kleiner ist als der Spalte Med_Preis
prob_gal = (df_Merged3['Gal_Preis'] < df_Merged3['Med_Preis']).mean()
print (f"Die Wahrscheinlichkeit, dass ein Produkt bei Galaxus günstiger ist als bei Media Markt beträgt {prob_gal:.2%}")
# Out:
# Die Wahrscheinlichkeit, dass ein Produkt bei Galaxus günstiger ist als bei Media Markt beträgt 64.42%

# %% [markdown]
# ##### Visualisierung Wahrscheinlichkeit

# %%
# Wahrscheinlichkeit, dass ein Produkt bei Media Markt günstiger ist
prob_med = 1 - prob_gal

# %%
labels = ['Galaxus', 'Media Markt']
prob = [prob_gal, prob_med]
plt.pie(prob, labels = labels, autopct='%1.1f%%')
plt.title('Wahtscheinlichkeit, dass ein Produkt günstiger ist')
plt.show()

# %% [markdown]
# #### Gibt es eine Korrelation zwischen der Marke und der Gesamsternebewertung?

# %%
# Als erstes erstellen wir ein neues Dataframe mit nur den zwei notwendigen Spalten. Die Index Spalte löschen wir.
df_Merged_corr = df_Merged3[['Marke','Med_Gesamtkundenbewertung']].reset_index(drop=True)

# %%
# löschen wir alle NAs raus.
df_Merged_corr = df_Merged_corr.dropna(subset=['Marke'])
df_Merged_corr = df_Merged_corr.dropna(subset=['Med_Gesamtkundenbewertung'])

# %%
#df_Merged_corr = df_Merged_corr[np.isfinite(df_Merged_corr['Med_Gesamtkundenbewertung'])]

# %%
# Für die Berechnung der Korrelation benötigen wir zwei numerische Variabeln.
# Variable Marke in numerische Werte 0-8 konvertieren
df_Merged_corr['Marke'] = df_Merged_corr['Marke'].map({'Samsung': 0, 'Apple': 1, 'Huawei': 2, 'Xiaomi': 3, 'Google': 4, 'Nokia': 5, 'OnePlus': 6, 'OPPO': 7, 'Motorola':8})
# Point Biserial Korrelation berechnen
corr, p_value = stats.pointbiserialr(df_Merged_corr['Marke'], df_Merged_corr['Med_Gesamtkundenbewertung'])

# %%
print('Point Biserial Correlation Coefficient:', corr)
print('P-value:', p_value)
# Out:
# Point Biserial Correlation Coefficient: -0.3312962413446292
# P-value: 1.0187958823579163e-06

# %%
# Als erstes haben wir die Marken in numerische Werte 0-8 geändert.
# 0 steht bei uns für Samsung, eine der bekanntesten Marken, während die letzte Zahl 8 für eine eher weniger bekannte Mark O steht.
# Somit wäre unsere Vermutung, dass hier eine negative Beziehung besteht.
# Mit der steigenden Zahl, die für die Marke steht, wird die Bewertung unserer Meinung nach schlechter.

# Im Allgemeinen heisst es, wenn der Koeffizient näher bei -1 ist, deutet dies auf eine starke negative Beziehung hin.
# Wichtig zu beachten in unserem Fall ist, dass der Koeffizient zwar im negativen Bereich, jedoch näher bei 0 als bei -1.
# Der Korrelationskoeffizient von -0.3312962413446292 zeigt eine mässig negative Korrelation zwischen den Variablen 'Marke' und 'Med_Gesamtkundenbewertung' an.
# Das bedeutet, dass tendenziell niedrigere Bewertungen bei verschiedenen Marken vorliegen.

# P-Value ist in unserem Fall sehr klein. Dieser Wert legt nahe, dass die beobachtete negative Korrelation sehr unwahrscheinlich nur durch Zufall entstanden ist.
# Die Nullhypothese, dass keine Korrelation zwischen der Marke und Bewrtung wird hiermit abgelehnt.
# P-Value weist auf eine statisch signifikante Korrelation zwischen den Variabeln hin.

# Unsere Schlussfolgerung basierend auf diesen zwei Werten wäre, dass zwischen den Variablen eine statistisch signifikante
# mässig negative Korrelation besteht. Das bedeutet, dass unterschiedliche Marken tendenziell unterschiedliche Bewerungen aufweisen, wobei bestimmte Marken mit niedrigeren Bewertungen in Verbindung gebracht werden können.
# Die weniger bekannten Marken können mit schlechteren Bewertungen in Verbindung gebracht werden.
# Je bekannter die Marke, umso bessere Bewertung.

# Was wir aber hier nicht aus den Augen verlieren dürfen ist, dass dieser Koeffizient und P-Wert stark von der Reihenfolge der erfassten Marken abhängt.
# Wenn wir die Reihenfolge abändern, ändern sicht auch der Wert. 

# Die Abbildung weiter unten zeigt die Verteilung der Bewertungen von jeder Marke. Anhand dieser Abbildung hat Apple die beste Bewertungen. Neben Apple hat OnePlus sehr gute Bewertungen.
# Sowohl bei der Berechnung des Koeffizienten wie auch bei der Abbildung wurde nicht beachtet wie viele Bewertungen pro Marke vorhanden sind.
# Wenn OnePlus nur zwei Bewertungen hat, aber dafür zwei sehr gute, kann man diese mit einer anderen Marke mit 100 Bewertungen vergleichen?

# Grundsätzlich gibt es Hinweise auf eine Korrelation.

# %%
sns.boxplot(data=df_Merged3, x='Marke', y='Med_Gesamtkundenbewertung')
plt.xlabel('Marke')
plt.ylabel('Bewertung')
plt.title('Korrelation zwischen Marke und Bewertung')
plt.show()
